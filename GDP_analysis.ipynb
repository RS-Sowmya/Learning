# %% [markdown]
# <a href="https://colab.research.google.com/github/RS-Sowmya/Learning/blob/main/GDP_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ef962124-ed41-4671-98a1-ba2568b68349" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef962124-ed41-4671-98a1-ba2568b68349">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('gdp.csv')

# %%
df.sample(6)
# Out:
#      Country Name Country Code  Year         Value
# 5355  Gambia, The          GMB  2002  5.782360e+08
# 7669   Mauritania          MRT  1962  1.111486e+08
# 8353    Nicaragua          NIC  2007  7.423377e+09
# 5483        Ghana          GHA  1999  7.719355e+09
# 4366   Costa Rica          CRI  2016  5.743551e+10
# 4662     Dominica          DMA  1991  1.804370e+08

# %%
df.describe(include = 'all')
# Out:
#                   Country Name Country Code          Year         Value
# count                    11507        11507  11507.000000  1.150700e+04
# unique                     256          256           NaN           NaN
# top     Caribbean small states          CSS           NaN           NaN
# freq                        57           57           NaN           NaN
# mean                       NaN          NaN   1991.265230  1.005972e+12
# std                        NaN          NaN     15.886648  4.533056e+12
# min                        NaN          NaN   1960.000000  8.824448e+06
# 25%                        NaN          NaN   1978.000000  2.056874e+09
# 50%                        NaN          NaN   1993.000000  1.436880e+10
# 75%                        NaN          NaN   2005.000000  1.796394e+11
# max                        NaN          NaN   2016.000000  7.904923e+13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11507 entries, 0 to 11506
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  11507 non-null  object
#  1   Country Code  11507 non-null  object
#  2   Year          11507 non-null  int64
#  3   Value         11507 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 359.7+ KB

# %%
# analysis one country
df_India = df[df['Country Name'] == 'India']
df_India.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (10,4),grid = 'True')
# Out:
# <Axes: xlabel='Year'>
